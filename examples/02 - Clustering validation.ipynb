# %% [markdown]
# # Clustering validation

# %% [markdown]
# ## importing libraries

# %%
# %matplotlib inline
import numpy as np
from fcmeans import FCM
from matplotlib import pyplot as plt

# %% [markdown]
# ## creating artificial data set

# %%
n_samples = 3000

X = np.concatenate((
    np.random.normal((-2, -2), size=(n_samples, 2)),
    np.random.normal((2, 2), size=(n_samples, 2)),
    np.random.normal((9, 0), size=(n_samples, 2)),
    np.random.normal((5, -8), size=(n_samples, 2))
))

plt.figure(figsize=(5, 5))
plt.scatter(X[:,0], X[:,1], alpha=.1)
plt.show()

# %% [markdown]
# # fitting the fuzzy-c-means
#  - create models with 2, 3, 4, 5, 6 and 6 centers

# %%
n_clusters_list = [2, 3, 4, 5, 6, 7]
models = list()
for n_clusters in n_clusters_list:
    fcm = FCM(n_clusters)
    fcm.fit(X)
    models.append(fcm)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# # showing results

# %%
# outputs
num_clusters = len(n_clusters_list)
rows = int(np.ceil(np.sqrt(num_clusters)))
cols = int(np.ceil(num_clusters / rows))
f, axes = plt.subplots(rows, cols, figsize=(11,16))
# axes[0][0].scatter(X[:,0], X[:,1], alpha=.1)
for i, tmp in enumerate(zip(n_clusters_list, axes.ravel())):
    n_clusters, axe = tmp
    # get partition coefficient
    pc = models[i].partition_coefficient
    
    fcm_centers = models[i].centers
    fcm_labels = models[i].predict(X)
    # plot result
    axe.scatter(X[:,0], X[:,1], c=fcm_labels, alpha=.1)
    axe.scatter(fcm_centers[:,0], fcm_centers[:,1], marker="+", s=500, c='black')
    axe.set_title(f'n_clusters = {n_clusters}, partition coefficient = {pc:.3f}')
plt.show()

# %% [markdown]
# note that the model with 4 clusters obtained the highest partition coefficient value for this example.
